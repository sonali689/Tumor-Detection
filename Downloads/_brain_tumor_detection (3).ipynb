# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.utils import to_categorical
from PIL import Image

data_dir = r'C:\Users\dubey\Downloads\Brain Tumor'  
categories = ['no', 'yes']

data = []
labels = []

for category in categories:
    path = os.path.join(data_dir, category)
    print(f"Loading images from: {path}")  
    class_num = categories.index(category)
    for img_name in os.listdir(path):
        try:
            img_path = os.path.join(path, img_name)
            img = Image.open(img_path)  
            img = img.resize((128, 128))  
            img = img.convert('RGB')  
            img_array = img_to_array(img)
            data.append(img_array)
            labels.append(class_num)
        except Exception as e:
            print(f"Error loading image {img_name}: {e}")

# Checking the shape of images
shapes = [img.shape for img in data]
unique_shapes = set(shapes)
print(f"Unique image shapes: {unique_shapes}")

if len(unique_shapes) == 1:
    data = np.array(data)
    labels = np.array(labels)
else:
    print("Error: Inconsistent image shapes found, cannot convert to NumPy array.")

if isinstance(data, list):
    data = np.array(data)
if isinstance(labels, list):
    labels = np.array(labels)

print(f"Dataset shape: {data.shape}")
print(f"Labels shape: {labels.shape}")

# Normalization 
data = data / 255.0

# labels to categorical
labels = to_categorical(labels, num_classes=2)

from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, random_state=42)

from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2
)

val_datagen = ImageDataGenerator()

train_generator = train_datagen.flow(X_train, y_train, batch_size=32)
val_generator = val_datagen.flow(X_val, y_val, batch_size=32)

# CNN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(2, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

history = model.fit(train_generator, epochs=20, validation_data=val_generator)

from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
import seaborn as sns

val_loss, val_acc = model.evaluate(val_generator)
print(f"Validation Accuracy: {val_acc * 100:.2f}%")

y_pred = model.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_val, axis=1)

# Classification report
print(classification_report(y_true, y_pred_classes, target_names=categories))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
plt.savefig('confusion_matrix.png')

# ROC-AUC
y_val_binary = np.argmax(y_val, axis=1)
y_pred_binary = y_pred[:, 1]
fpr, tpr, _ = roc_curve(y_val_binary, y_pred_binary)
roc_auc = roc_auc_score(y_val_binary, y_pred_binary)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
plt.savefig('roc_curve.png')
# Out:
# Loading images from: C:\Users\dubey\Downloads\Brain Tumor\no
# Loading images from: C:\Users\dubey\Downloads\Brain Tumor\yes
# Unique image shapes: {(128, 128, 3)}
# Dataset shape: (253, 128, 128, 3)
# Labels shape: (253,)
# C:\Users\dubey\Anaconda\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 57600)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │     7,372,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,392,578 (28.20 MB)
#  Trainable params: 7,392,578 (28.20 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# C:\Users\dubey\Anaconda\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step - accuracy: 0.5341 - loss: 1.1038 - val_accuracy: 0.8235 - val_loss: 0.5789
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.6080 - loss: 0.6484 - val_accuracy: 0.6078 - val_loss: 0.6178
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - accuracy: 0.6429 - loss: 0.6286 - val_accuracy: 0.6471 - val_loss: 0.5840
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - accuracy: 0.6919 - loss: 0.6067 - val_accuracy: 0.6471 - val_loss: 0.5827
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.6604 - loss: 0.5972 - val_accuracy: 0.7843 - val_loss: 0.5411
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - accuracy: 0.7120 - loss: 0.5998 - val_accuracy: 0.6275 - val_loss: 0.5714
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.7134 - loss: 0.5881 - val_accuracy: 0.8235 - val_loss: 0.5025
# Epoch 8/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.6807 - loss: 0.6006 - val_accuracy: 0.7451 - val_loss: 0.5230
# Epoch 9/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - accuracy: 0.6953 - loss: 0.5968 - val_accuracy: 0.7843 - val_loss: 0.5075
# Epoch 10/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.7256 - loss: 0.5504 - val_accuracy: 0.6863 - val_loss: 0.5363
# Epoch 11/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.7213 - loss: 0.5490 - val_accuracy: 0.7059 - val_loss: 0.5416
# Epoch 12/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.6876 - loss: 0.5987 - val_accuracy: 0.6078 - val_loss: 0.6335
# Epoch 13/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.6024 - loss: 0.6741 - val_accuracy: 0.7647 - val_loss: 0.5777
# Epoch 14/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 195ms/step - accuracy: 0.7062 - loss: 0.5940 - val_accuracy: 0.8431 - val_loss: 0.5322
# Epoch 15/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.7064 - loss: 0.5733 - val_accuracy: 0.8431 - val_loss: 0.4694
# Epoch 16/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.7020 - loss: 0.5481 - val_accuracy: 0.6471 - val_loss: 0.5594
# Epoch 17/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.7266 - loss: 0.5540 - val_accuracy: 0.8431 - val_loss: 0.4614
# Epoch 18/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - accuracy: 0.7633 - loss: 0.4926 - val_accuracy: 0.7843 - val_loss: 0.4857
# Epoch 19/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - accuracy: 0.7164 - loss: 0.6070 - val_accuracy: 0.8627 - val_loss: 0.4333
# Epoch 20/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.7066 - loss: 0.5422 - val_accuracy: 0.8039 - val_loss: 0.4451
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8068 - loss: 0.4574
# Validation Accuracy: 80.39%
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
#               precision    recall  f1-score   support
#
#           no       0.86      0.60      0.71        20
#          yes       0.78      0.94      0.85        31
#
#     accuracy                           0.80        51
#    macro avg       0.82      0.77      0.78        51
# weighted avg       0.81      0.80      0.80        51
